# %%
import pandas as pd
import numpy as np

# %%
a = pd.read_excel('/Users/chaelin/PycharmProjects/pythonProject2/files/건강.xlsx')
b = pd.read_excel('/Users/chaelin/PycharmProjects/pythonProject2/files/마음건강.xlsx')
c = pd.read_excel('/Users/chaelin/PycharmProjects/pythonProject2/files/맛집.xlsx')
d = pd.read_excel('/Users/chaelin/PycharmProjects/pythonProject2/files/명소.xlsx')
e = pd.read_excel('/Users/chaelin/PycharmProjects/pythonProject2/files/요리.xlsx')
f = pd.read_excel('/Users/chaelin/PycharmProjects/pythonProject2/files/취미.xlsx')
g = pd.read_excel('/Users/chaelin/PycharmProjects/pythonProject2/files/투자.xlsx')

# %%
list = ['건강','힐링','맛집','명소','요리','취미','투자']
df = [a,b,c,d,e,f,g]
for i in range(len(df)):
    df[i]['label'] = list[i]

# %%
health = []
for i in range(len(a.index)):
    temp = a.iloc[i,5]
    word_num = []
    for v in range(len(temp)):
        ref = a.iloc[0,5][1]
        x = temp[v]
        if x == ref:
            word_num.append(v)
    for t in range(0,len(word_num),2):
        num1 = word_num[t]
        num2 = word_num[t+1]
        w = temp[num1+2:num2]
        health.append(w)

health
# Out:
# ['⛰️',
#  'daily',
#  'dailypic',
#  '일상',
#  '운동',
#  '건강',
#  '등산',
#  '하이킹',
#  '혼산',
#  '혼등',
#  '원적산',
#  '원적산정상',
#  '산이좋다',
#  '산에가자',
#  '오등완',
#  '오운완',
#  '산린이',
#  '등린이',
#  '한남정맥',
#  '쿠쿠네밥상',
#  '연근조림연근식초물에잠깐담궜다만능간장으로졸여줌살짝데쳐야쪼그라들지않음~~귀찮아도꼭!!!데쳐야겠어요',
#  '계란말이크래미맛살대파다져서맛술마늘소금',
#  '콩나물무침',
#  '무생채',
#  '새우꽈리고추조림',
#  '묵은지들기름볶음',
#  '사과케이크사과박력분녹인버터설탕계란베이킹파우더식어도넘맛난케이크강추에용',
#  '집밥',
#  '홈쿡',
#  '집쿡',
#  '푸드',
#  '요리',
#  '취미',
#  '소소한',
#  '일상',
#  '건강',
#  '행복',
#  '명언',
#  '자기계발',
#  '동기부여',
#  '성공',
#  '부자',
#  '경제적자유',
#  '좋은말',
#  '인생명언',
#  '인생글귀',
#  '명언',
#  '도전',
#  '생각',
#  '목표',
#  '목표달성',
#  '노력',
#  '자수성가',
#  '성장',
#  '배움',
#  '꾸준함',
#  '건강',
#  '대화',
#  '소통',
#  '마음가짐',
#  '불안',
#  '습관',
#  '쿠쿠네밥상',
#  '무우유부국',
#  '함박스테이크',
#  '콩나물무침',
#  '계란말이',
#  '연근조림',
#  '무생채',
#  '꽈리고추새우볶음',
#  '묵은지들기름볶음',
#  '집밥',
#  '홈쿡',
#  '집쿡',
#  '푸드',
#  '요리',
#  '취미',
#  '소소한',
#  '일상',
#  '건강',
#  '행복',
#  '힘피트니스',
#  '뉴텍',
#  '운동은힘핏',
#  '광양헬스',
#  '광양피티',
#  '광양필라테스',
# ...

# %%
healing = []
for i in range(len(b.index)):
    temp = b.iloc[i,5]
    word_num = []
    for v in range(len(temp)):
        ref = b.iloc[0,5][1]
        x = temp[v]
        if x == ref:
            word_num.append(v)
    for t in range(0,len(word_num),2):
        num1 = word_num[t]
        num2 = word_num[t+1]
        w = temp[num1+2:num2]
        healing.append(w)

healing
# Out:
# ['작은콩의류마티스그림일기',
#  '뜻밖의응원',
#  '사진크루사이',
#  '뜻밖의응원',
#  '포리메이트',
#  '사천시',
#  '사천시청',
#  '사천시보건소',
#  '사천시정신건강복지센터',
#  '찾아가는심리지원서비스',
#  '우리동네공감상담소',
#  '마음건강',
#  '심리상담',
#  '무료상담',
#  '뜻밖의응원',
#  '스페셜도슨트',
#  '건강한뉴스를원해',
#  '희소식무소식',
#  '사람건강',
#  '마음건강',
#  '지구건강',
#  'buttercreamflower',
#  'buttercream',
#  'buttercake',
#  'flowercake',
#  'flowers',
#  'weddingcake',
#  'cupcakes',
#  'cakedecorating',
#  'flowerpiping',
#  'koreanflowercake',
#  'beancreamflower',
#  '버터플라워',
#  '앙금플라워',
#  '플라워케이크',
#  '웰니스컬리지1기[',
#  '웰니스',
#  '웰니스프로그램',
#  '용평리조트',
#  '마음챙김',
#  '대학생',
#  '대외활동',
#  '마음건강',
#  '정신건강',
#  '대학생공스타그램',
#  '대학생공스타',
#  '대외활동추천',
#  '청년인재양성과정',
#  '용평리조트',
#  'ESG경영',
#  '간호학과',
#  '간호학과공스타그램',
#  '간호학과공스타',
#  '간호공스타',
#  '간호학과대외활동',
#  '요가',
#  '색채명상',
#  '컬러링북',
#  '먹기명상',
#  '산소발자국',
#  '고용노동부',
#  '웰니스전문가',
#  '싱잉볼',
#  '웰니스관광',
#  '힐링',
#  '평창',
#  '웰니스컬리지1기[',
#  '웰니스',
#  '웰니스프로그램',
#  '용평리조트',
#  '마음챙김',
#  '대학생',
#  '대외활동',
#  '마음건강',
#  '정신건강',
# ...

# %%
restaurant = []
for i in range(len(c.index)):
    temp = c.iloc[i,5]
    word_num = []
    for v in range(len(temp)):
        ref = c.iloc[0,5][1]
        x = temp[v]
        if x == ref:
            word_num.append(v)
    for t in range(0,len(word_num),2):
        num1 = word_num[t]
        num2 = word_num[t+1]
        w = temp[num1+2:num2]
        restaurant.append(w)

restaurant
# Out:
# ['태태삼겹',
#  '건대',
#  '건대맛집',
#  '건대입구맛집',
#  '건대입구',
#  '건대입구역맛집',
#  '건대데이트',
#  '건대데이트코스',
#  '건대입구맛집추천',
#  '건대입구역맛집추천',
#  '건대핫플',
#  '성수',
#  '성수동맛집',
#  '성수동데이트',
#  '성수맛집',
#  'foodporn',
#  'foodie',
#  'foodstagram',
#  'instafood',
#  'food',
#  '맛집',
#  '맛집추천',
#  '먹스타그램',
#  '고기',
#  '고기맛집',
#  '스튜부대',
#  '신사동',
#  '신사동맛집',
#  '신사동데이트',
#  '압구정로데오',
#  '압구정로데오맛집',
#  '압구정로데오핫플',
#  '압구정로데오역맛집',
#  '압구정로데오맛집추천',
#  '압구정',
#  '압구정맛집',
#  '압구정맛집추천',
#  '압구정데이트',
#  '압구정데이트맛집',
#  'food',
#  'foodporn',
#  'foodie',
#  'foodstagram',
#  'instafood',
#  '맛집',
#  '맛집추천',
#  '먹스타그램',
#  '먹스타맞팔',
#  '데이트코스',
#  '데이트코스추천',
#  '오복집',
#  '오복집이미',
#  '대잇팅_강서',
#  '후소이살몬',
#  '행리단길',
#  '행리단길맛집',
#  '행리단길핫플',
#  '행리단길데이트',
#  '행리단길맛집추천',
#  '수원',
#  '수원맛집',
#  '수원맛집추천',
#  '수원데이트',
#  '수원데이트코스',
#  '팔달구맛집',
#  '스테이크',
#  '스테이크맛집',
#  '스테이크맛집추천',
#  'steak',
#  'food',
#  'foodporn',
#  'foodie',
#  'foodstagram',
#  'instafood',
#  '맛집',
#  '맛집추천',
#  '먹스타그램',
#  '먹스타맞팔',
# ...

# %%
place = []
for i in range(len(d.index)):
    temp = d.iloc[i,5]
    word_num = []
    for v in range(len(temp)):
        ref = d.iloc[0,5][1]
        x = temp[v]
        if x == ref:
            word_num.append(v)
    for t in range(0,len(word_num),2):
        num1 = word_num[t]
        num2 = word_num[t+1]
        w = temp[num1+2:num2]
        place.append(w)

place
# Out:
# ['배롱나무',
#  '명소',
#  '달성',
#  '삼가헌',
#  '칠곡',
#  '가실성당',
#  '하목정',
#  '육신사',
#  '대구',
#  '신숭겸장군유적지',
#  '대구여행',
#  '대구가볼만한곳',
#  '여름여행',
#  '여름꽃',
#  '목백일홍',
#  '하이바다테이블에',
#  '하이바다📍인천',
#  '데이트코스',
#  '데이트코스추천',
#  '여행',
#  '가볼만한곳',
#  '바다',
#  '맛집추천',
#  '카페추천',
#  '춘천핫플',
#  '핫플',
#  '신상핫플',
#  '신상맛집',
#  '국내여행',
#  '여행지추천',
#  '춘천여행코스추천',
#  '신상카페',
#  '데이트코스추천',
#  '핫플레이스',
#  '가볼만한곳',
#  '감성숙소',
#  '숙소추천',
#  '드라이브',
#  '드라이브코스',
#  '국내명소',
#  '명소',
#  '포토존',
#  '국내여행',
#  '벚꽃',
#  '개화시기',
#  '명소',
#  '벚꽃명소',
#  '꿀팁',
#  '꽃길',
#  '명소',
#  '코스모스',
#  '천일홍',
#  '금계국',
#  '봉사',
#  '노력',
#  '폭염',
#  '부석',
#  '간월호',
#  '관심',
#  '성원',
#  '회의',
#  '행복',
#  '참여하신',
#  '당진',
#  '여행',
#  '아미미술관',
#  '수국',
#  '명소',
#  'FortCanningPark',
#  'FortCanningParkTreeTunnel',
#  'フォートカニング公園.....【TRIPROUD】☑世界で最もフォトジェニックな『おでかけSNS』☑現在10',
#  'Singapore',
#  'シンガポール',
#  'シンガポール観光',
#  'シンガポール旅行',
#  '海外旅行',
#  'カメラ女子',
#  'TRIPROUD',
#  '안성팜랜드',
#  '안성팜랜드📍',
#  '데이트코스',
#  '데이트코스추천',
#  '여행',
# ...

# %%
cooking = []
for i in range(len(e.index)):
    temp = e.iloc[i,5]
    word_num = []
    for v in range(len(temp)):
        ref = e.iloc[0,5][1]
        x = temp[v]
        if x == ref:
            word_num.append(v)
    for t in range(0,len(word_num),2):
        num1 = word_num[t]
        num2 = word_num[t+1]
        w = temp[num1+2:num2]
        cooking.append(w)

cooking
# Out:
# ['통영',
#  '해녀',
#  '뿔소라',
#  '소라무침',
#  '소라',
#  '뿔소라무침',
#  '술안주',
#  '시골청년',
#  '먹스타그램',
#  '맛스타그램',
#  '요리',
#  '요리스타그램',
#  '집밥',
#  '집밥레시피',
#  '요리레시피',
#  '홈쿡',
#  '홈쿡레시피',
#  '먹방',
#  '먹팔',
#  '맞팔',
#  '요리하는남자',
#  '골뱅이무침',
#  '홈파티',
#  '막걸리안주',
#  '소주안주',
#  '홈술',
#  '혼술',
#  '집술',
#  '간단요리',
#  '간단레시피',
#  '먹방',
#  '먹스타그램',
#  '요리',
#  '요리스타그램',
#  '취미',
#  '영화',
#  '영화추천',
#  '음악',
#  '음악추천',
#  '최신가요',
#  '노래',
#  '노래추천',
#  '먹방',
#  '먹스타그램',
#  '요리',
#  '요리스타그램',
#  '취미',
#  '영화',
#  '영화추천',
#  '음악',
#  '음악추천',
#  '최신가요',
#  '노래',
#  '노래추천',
#  '통삼겹',
#  '크리스피',
#  '오븐구이',
#  '에어프라이어',
#  '에어프라이어요리',
#  '통삼겹구이',
#  '도무스',
#  '양면스텐도마',
#  '먹스타그램',
#  '맛스타그램',
#  '홈파티',
#  '집밥',
#  '집밥스타그램',
#  '요리',
#  '요리스타그램',
#  '집밥레시피',
#  '홈쿡레시피',
#  '홈쿡',
#  '먹방',
#  '먹팔',
#  '맞팔',
#  '바비큐',
#  '통삼겹오븐구이',
#  '삼겹살',
#  '인천맛집',
#  '맛집스타그램',
#  '요리하는남자',
#  '에어프라이어삼겹살',
#  '묵사발',
#  '유부초밥',
#  '칠리새우',
#  '집밥',
#  '집밥스타그램',
#  '집밥레시피',
#  '홈쿡',
#  '홈쿡스타그램',
#  '홈쿡레시피',
#  '맛스타그램',
# ...

# %%
hobby = []
for i in range(len(f.index)):
    temp = f.iloc[i,5]
    word_num = []
    for v in range(len(temp)):
        ref = f.iloc[0,5][1]
        x = temp[v]
        if x == ref:
            word_num.append(v)
    for t in range(0,len(word_num),2):
        num1 = word_num[t]
        num2 = word_num[t+1]
        w = temp[num1+2:num2]
        hobby.append(w)

hobby
# Out:
# ['먹방',
#  '먹스타그램',
#  '요리',
#  '요리스타그램',
#  '취미',
#  '영화',
#  '영화추천',
#  '음악',
#  '음악추천',
#  '최신가요',
#  '노래',
#  '노래추천',
#  '아이패드캘리',
#  '아이패드일러스트',
#  '오늘도힘',
#  '캘리언의예쁜손글씨',
#  '캘리언숍',
#  '오일파스텔',
#  '오일파스텔드로잉',
#  '손그림',
#  '풍경그림',
#  '풍경화',
#  '꽃밭풍경',
#  '취미',
#  '그림스타그램',
#  '조용한오리',
#  'oilpastel',
#  'oilpasteldrawing',
#  'landscapedrawing',
#  'flowerlandscape',
#  '토피슬라임',
#  '꿈틀이캔디',
#  '백숙_토피',
#  '장용석의내차를부탁해',
#  '내차를부탁해',
#  '미션오일',
#  '냉각수첨가제',
#  'bmw',
#  '사람사는세상',
#  '뼈속까지친노',
#  '노무현재단',
#  '여행',
#  '맛집',
#  '한강',
#  '안주',
#  '세차',
#  '디테일링',
#  '볼링',
#  '등산',
#  '취미',
#  '운동',
#  '싸이클',
#  '찜질방',
#  '데이트코스',
#  '드라이브',
#  '핫플',
#  '인싸',
#  '좋반',
#  '은평구',
#  '연신내맛집',
#  '응암맛집',
#  '새절맛집',
#  '사랑하는_너와함께_오늘도_행복해💞',
#  '먹방',
#  '먹스타그램',
#  '요리',
#  '요리스타그램',
#  '취미',
#  '영화',
#  '영화추천',
#  '음악',
#  '음악추천',
#  '최신가요',
#  '노래',
#  '노래추천',
#  '먹방',
#  '먹스타그램',
#  '요리',
#  '요리스타그램',
#  '취미',
#  '영화',
#  '영화추천',
#  '음악',
#  '음악추천',
#  '최신가요',
#  '노래',
#  '노래추천',
# ...

# %%
investment = []
for i in range(len(g.index)):
    temp = g.iloc[i,5]
    word_num = []
    for v in range(len(temp)):
        ref = g.iloc[0,5][1]
        x = temp[v]
        if x == ref:
            word_num.append(v)
    for t in range(0,len(word_num),2):
        num1 = word_num[t]
        num2 = word_num[t+1]
        w = temp[num1+2:num2]
        investment.append(w)

investment
# Out:
# ['1',
#  '순살',
#  '경제단어',
#  '순살',
#  '공감',
#  '신사임당',
#  '디피',
#  '브랜딩',
#  '투자',
#  '브랜드만드는남자',
#  '브만남',
#  '투자',
#  '소액투자',
#  '폰테크',
#  '앱테크',
#  '육아맘부업',
#  '산모교실',
#  '재무설계사',
#  '딸맘',
#  '애엄마',
#  '30대맘',
#  '재테크수아',
#  '투자',
#  '소비',
#  '절약',
#  '자본주의',
#  '자본주의산책',
#  '망둥이',
#  '다시읽기',
#  '하루문장📕',
#  '임자와임장안녕하세요.',
#  '부동산공부',
#  '부동산',
#  '부동산투자',
#  '돈공부',
#  '경제적자유',
#  '부린이',
#  '경제공부',
#  '갭투자',
#  '부동산경매',
#  '오피스텔',
#  '카드뉴스',
#  '자기계발',
#  '동기부여',
#  '투자',
#  '투자공부',
#  '재테크하는부부',
#  '재테크',
#  '돈공부',
#  '파이어족',
#  '파이어',
#  '경제공부',
#  '짠테크',
#  '절약',
#  '가계부',
#  '주식',
#  '주린이',
#  '부린이',
#  '코린이',
#  '주식',
#  '부동산',
#  '코인',
#  '경제적자유',
#  '주식공부',
#  '부동산공부',
#  '내꿈은과소비',
#  '내일의행복',
#  '부동산투자',
#  '투자',
#  '재개발',
#  '재건축',
#  '임장',
#  '수페tv',
#  'etf',
#  'etf투자',
#  '젊줌맘',
#  '투자',
#  '재테크상담',
#  '선팔',
#  '맞팔',
#  '인친',
#  '인친환영',
#  '인친해요',
#  '데일리',
#  '선팔환영',
#  '소통',
#  '집에서돈벌기',
#  '돈모으기',
#  '문의환영',
#  'cafe',
#  '투자',
#  '자산',
#  '부동산',
#  '부채',
# ...

# %%
#health = health.astype(str)
import numpy as np
np_array = np.array(health)
health_data = np_array.astype(str) 
np_array = np.array(healing)
healing_data = np_array.astype(str) 
np_array = np.array(restaurant)
restaurant_data = np_array.astype(str) 
np_array = np.array(place)
place_data = np_array.astype(str) 
np_array = np.array(cooking)
cooking_data = np_array.astype(str) 
np_array = np.array(hobby)
hobby_data = np_array.astype(str) 
np_array = np.array(investment)
investment_data = np_array.astype(str)

# %%
from gensim import corpora

# %%
from gensim.models import Word2Vec
health_data = Word2Vec( str(health_data), vector_size = 100, window = 3, min_count=1, epochs=100, sg=1)
healing_data = Word2Vec( str(healing_data), vector_size = 100, window = 3, min_count=1, epochs=100, sg=1)
restaurant_data = Word2Vec( str(restaurant_data), vector_size = 100, window = 3, min_count=1, epochs=100, sg=1)
place_data = Word2Vec( str(place_data), vector_size = 100, window = 3, min_count=1, epochs=100, sg=1)
cooking_data = Word2Vec( str(cooking_data), vector_size = 100, window = 3, min_count=1, epochs=100, sg=1)
hobby_data = Word2Vec( str(hobby_data), vector_size = 100, window = 3, min_count=1, epochs=100, sg=1)
investment_data = Word2Vec( str(investment_data), vector_size = 100, window = 3, min_count=1, epochs=100, sg=1)

# %%
id2word=corpora.Dictionary(health_data)
id2word.filter_extremes(no_below = 20) #20회 이하로 등장한 단어는 삭제
corpus=[id2word.doc2bow(text) for text in health_data]
mallet_path = '/Users/chaelin/PycharmProjects/pythonProject2/mallet-2.0.8/bin/mallet' 
ldamallet = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=10, id2word=id2word)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/chaelin/PycharmProjects/pythonProject2/input_creator.ipynb Cell 14 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/chaelin/PycharmProjects/pythonProject2/input_creator.ipynb#ch0000013?line=0'>1</a> id2word=corpora.Dictionary(health_data)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gensim/corpora/dictionary.py:78, in Dictionary.__init__(self, documents, prune_at)
#      75 self.num_nnz = 0
#      77 if documents is not None:
# ---> 78     self.add_documents(documents, prune_at=prune_at)
#      79     self.add_lifecycle_event(
#      80         "created",
#      81         msg=f"built {self} from {self.num_docs} documents (total {self.num_pos} corpus positions)",
#      82     )
#
# ...

# %%
coherence_model_ldamallet = CoherenceModel(model=ldamallet, texts=texts, dictionary=id2word, coherence='c_v')
coherence_ldamallet = coherence_model_ldamallet.get_coherence()


def compute_coherence_values(dictionary, corpus, texts, limit, start=4, step=2):

    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=id2word)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=data_word, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values



# Can take a long time to run.
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=texts, start=4, limit=21, step=2)




limit=21; start=4; step=2;
x = range(start, limit, step)
topic_num = 0
count = 0
max_coherence = 0
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", cv)
    coherence = cv
    if coherence >= max_coherence:
        max_coherence = coherence
        topic_num = m
        model_list_num = count   
    count = count+1

        
# Select the model and print the topics
optimal_model = model_list[model_list_num]
model_topics = optimal_model.show_topics(formatted=False)
#print(optimal_model.print_topics(num_words=10))








def format_topics_sentences(ldamodel=optimal_model, corpus=corpus, texts=texts):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    #ldamodel[corpus]: lda_model에 corpus를 넣어 각 토픽 당 확률을 알 수 있음
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num,topn=10)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']
    print(type(sent_topics_df))

    # Add original text to the end of the output
    #contents = pd.Series(texts)
    #sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    sent_topics_df = pd.concat([sent_topics_df, Data['text'],Data['timestamp'],Data['tweet_url'],Data['screen_name'],Data['label']], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=optimal_model, corpus=corpus, texts=Data_list)

# Format
df_topic_tweet = df_topic_sents_keywords.reset_index()
df_topic_tweet.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text','Timestamp', 'Tweet_url','Screen_name','label']

# Show각 문서에 대한 토픽
#df_dominant_topic=df_dominant_topic.sort_values(by=['Dominant_Topic'])
#df_topic_tweet








# Group top 5 sentences under each topic
sent_topics_sorteddf_mallet = pd.DataFrame()

sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, 
                                             grp.sort_values(['Perc_Contribution'], ascending=[0]).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)


topic_counts = df_topic_sents_keywords['Dominant_Topic'].value_counts()
topic_counts.sort_index(inplace=True)

topic_contribution = round(topic_counts/topic_counts.sum(), 4)
topic_contribution

lda_inform = pd.concat([sent_topics_sorteddf_mallet, topic_counts, topic_contribution], axis=1)
lda_inform.columns=["Topic_Num", "Topic_Perc_Contrib", "Keywords", "Text", "timestamp", "tweet_url","screen_name","label","Num_Documents", "Perc_Documents"]
lda_inform = lda_inform[["Topic_Num","Keywords","Num_Documents","Perc_Documents"]]
lda_inform
#lda_inform.Topic_Num = lda_inform.Topic_Num.astype(int)
lda_inform['Topic_Num'] =lda_inform['Topic_Num'] +1
lda_inform.Topic_Num = lda_inform.Topic_Num.astype(str)
lda_inform['Topic_Num'] =lda_inform['Topic_Num'].str.split('.').str[0]
df_topic_tweet['Dominant_Topic'] =df_topic_tweet['Dominant_Topic'] +1
df_topic_tweet.Dominant_Topic = df_topic_tweet.Dominant_Topic.astype(str)
df_topic_tweet['Dominant_Topic'] =df_topic_tweet['Dominant_Topic'].str.split('.').str[0]

# %%
from gensim.models import LdaModel

def mallet_to_lda(optimal_model):
    model_gensim = LdaModel(
        id2word=optimal_model.id2word, num_topics=optimal_model.num_topics,
        alpha=optimal_model.alpha, eta=0, iterations=1000,
        gamma_threshold=0.001,
        dtype=np.float32
    )
    model_gensim.sync_state()
    model_gensim.state.sstats = optimal_model.wordtopics
    return model_gensim
model = mallet_to_lda(optimal_model)

import pyLDAvis
import pyLDAvis.gensim

pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(model, corpus, id2word)
vis
